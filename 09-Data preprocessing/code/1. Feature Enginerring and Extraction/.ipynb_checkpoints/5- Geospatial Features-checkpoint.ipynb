# %% [markdown]
# # Geospatial Features
# In this notebook we will learn about geographic data and how to work with them
# <br>
# we will use this library: https://github.com/risenW/datasisthttps://github.com/risenW/datasist

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 10)}, font_scale=1.2)

# %% [markdown]
# ### Measuring Distance

# %%
from datasist.feature_engineering import haversine_distance

# lat, long
my_home = [30.109919, 31.308797]
cafe = [30.120982, 31.322026]

# %%
haversine_distance(my_home[0], my_home[1], cafe[0], cafe[1])
# Out:
# 0    1.769848
# dtype: float64

# %% [markdown]
# ### Get Center Location between 2 points

# %%
from datasist.feature_engineering import get_location_center

get_location_center(my_home[0], cafe[0]), get_location_center(my_home[1], cafe[1])
# Out:
# (0    30.115451
#  dtype: float64,
#  0    31.315411
#  dtype: float64)

# %% [markdown]
# ## So Lets use it with Our data

# %%
df = pd.read_csv('../dastasets/sendy_logistics.csv')
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
df['Dist_Pick_Dest'] = haversine_distance(df['Pickup Lat'], df['Pickup Long'], df['Destination Lat'], df['Destination Long'])
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Distance (KM)  Temperature  \
# 0                                5  ...             4         20.4
# 1                                5  ...            16         26.4
# 2                                2  ...             3          NaN
# 3                                5  ...             9         19.2
# 4                                1  ...             9         15.4
#
#    Precipitation in millimeters Pickup Lat  Pickup Long  Destination Lat  \
# 0                           NaN  -1.317755    36.830370        -1.300406
# 1                           NaN  -1.351453    36.899315        -1.295004
# 2                           NaN  -1.308284    36.843419        -1.300921
# 3                           NaN  -1.281301    36.832396        -1.257147
# 4                           NaN  -1.266597    36.792118        -1.295041
#
#   Destination Long      Rider Id  Time from Pickup to Arrival Dist_Pick_Dest
# 0        36.829741  Rider_Id_432                          745       1.930333
# 1        36.814358  Rider_Id_856                         1993      11.339849
# 2        36.828195  Rider_Id_155                          455       1.880079
# 3        36.795063  Rider_Id_855                         1341       4.943458
# 4        36.809817  Rider_Id_770                         1214       3.724829
#
# [5 rows x 30 columns]

# %%
df['Center_Lat'] = get_location_center(df['Pickup Lat'], df['Destination Lat'])
df['Center_Long'] = get_location_center(df['Pickup Long'], df['Destination Long'])
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Precipitation in millimeters  \
# 0                                5  ...                          NaN
# 1                                5  ...                          NaN
# 2                                2  ...                          NaN
# 3                                5  ...                          NaN
# 4                                1  ...                          NaN
#
#    Pickup Lat  Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0   -1.317755    36.830370       -1.300406         36.829741  Rider_Id_432
# 1   -1.351453    36.899315       -1.295004         36.814358  Rider_Id_856
# 2   -1.308284    36.843419       -1.300921         36.828195  Rider_Id_155
# 3   -1.281301    36.832396       -1.257147         36.795063  Rider_Id_855
# 4   -1.266597    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival  Dist_Pick_Dest  Center_Lat Center_Long
# 0                         745        1.930333   -1.309080   36.830056
# 1                        1993       11.339849   -1.323229   36.856837
# 2                         455        1.880079   -1.304603   36.835807
# 3                        1341        4.943458   -1.269224   36.813730
# 4                        1214        3.724829   -1.280819   36.800968
#
# [5 rows x 32 columns]

# %% [markdown]
# # Great Work!
