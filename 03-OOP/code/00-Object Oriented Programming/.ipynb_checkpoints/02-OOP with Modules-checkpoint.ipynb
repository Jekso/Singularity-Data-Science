# %% [markdown]
# ## Import Circle Class from Module

# %%
from my_package.CircleClass import Circle

# %%
c1 = Circle(10)

# %%
dir(c1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'getArea',
#  'getCircumference',
#  'pi',
#  'radius']

# %%
c1.getArea()
# Out:
# 314.0

# %%
c1.getCircumference()
# Out:
# 62.800000000000004

# %% [markdown]
# ## Import Calculator Class from Module

# %%
from my_package.CalculatorClass import Calculator

# %%
Calculator.summ(10, 20)
# Out:
# 30

# %%
Calculator.sub(10, 3)
# Out:
# 7

# %%
Calculator.mul(2, 100)
# Out:
# 200

# %%
Calculator.div(100, 5)
# Out:
# 20.0

# %%
Calculator.div(100, 0)
# Out:
# 'Cant divide on zero'

# %% [markdown]
# # Great Work!
