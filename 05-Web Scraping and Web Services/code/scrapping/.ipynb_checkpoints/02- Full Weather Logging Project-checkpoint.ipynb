# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

# %%
with open('messurments_log.txt', 'w') as f:
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.request('GET', url)
        soup = BeautifulSoup(response.text, 'html.parser')
        weather = soup.find('div', attrs={'class': 'temp'}).get_text()
        weather = float(weather.split('°')[0])
        wind = soup.find('div', attrs={'class': 'wind'}).get_text()
        wind = float(wind.split(' ')[1])
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                presure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")

        # Write to Txt file
        ############################################################################
        output = f"weather={weather}°C, wind={wind}°Km/h, humidity={humidity}%, visibility={visibility}m, presure={presure}mb at time {time_now}\n"
        f.write(output)
        ############################################################################
         
        print(f'scrapping done for {i+1} times at {time_now}')
        time.sleep(5)
# Out:
# scrapping done for 1 times at 07/06/2020 02:23:01
# scrapping done for 2 times at 07/06/2020 02:23:06
# scrapping done for 3 times at 07/06/2020 02:23:12
# scrapping done for 4 times at 07/06/2020 02:23:18
# scrapping done for 5 times at 07/06/2020 02:23:23
# scrapping done for 6 times at 07/06/2020 02:23:29
# scrapping done for 7 times at 07/06/2020 02:23:35
# scrapping done for 8 times at 07/06/2020 02:23:40
# scrapping done for 9 times at 07/06/2020 02:23:46
# scrapping done for 10 times at 07/06/2020 02:23:51

# %%
f = open('messurments_log.txt', 'r')
print(f.read())
f.close()
# Out:
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:01
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:06
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:12
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:18
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:23
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:29
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:35
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:40
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:46
# weather=24.0°C, wind=13.0°Km/h, humidity=44.0%, visibility=10000.0m, presure=1009.0mb at time 07/06/2020 02:23:51

# %%
import csv 


with open('messurments_log.csv', 'w') as f:
    fnames = ['weather', 'wind', 'humidity', 'visibility', 'presure', 'time_now']
    writer = csv.DictWriter(f, fieldnames=fnames)
    writer.writeheader()
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.request('GET', url)
        soup = BeautifulSoup(response.text, 'html.parser')
        weather = soup.find('div', attrs={'class': 'temp'}).get_text()
        weather = float(weather.split('°')[0])
        wind = soup.find('div', attrs={'class': 'wind'}).get_text()
        wind = float(wind.split(' ')[1])
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                presure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")

        # Write to Txt file
        ############################################################################
        output = {'weather': weather, 'wind': wind, 'humidity': humidity, 'visibility': visibility, 'presure': presure, 'time_now': time_now}
        writer.writerow(output)
        ############################################################################
        
        print(f'scrapping done for {i+1} times at {time_now}')
        time.sleep(5)
# Out:
# scrapping done for 1 times at 07/06/2020 02:23:59
# scrapping done for 2 times at 07/06/2020 02:24:06
# scrapping done for 3 times at 07/06/2020 02:24:12
# scrapping done for 4 times at 07/06/2020 02:24:18
# scrapping done for 5 times at 07/06/2020 02:24:23
# scrapping done for 6 times at 07/06/2020 02:24:29
# scrapping done for 7 times at 07/06/2020 02:24:35
# scrapping done for 8 times at 07/06/2020 02:24:40
# scrapping done for 9 times at 07/06/2020 02:24:46
# scrapping done for 10 times at 07/06/2020 02:24:52

# %%
import pandas as pd

data = pd.read_csv('messurments_log.csv')
data
# Out:
#    weather  wind  humidity  visibility  presure             time_now
# 0     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:23:59
# 1     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:06
# 2     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:12
# 3     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:18
# 4     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:23
# 5     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:29
# 6     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:35
# 7     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:40
# 8     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:46
# 9     24.0  13.0      44.0     10000.0   1009.0  07/06/2020 02:24:52

# %% [markdown]
# ## Good Job!
