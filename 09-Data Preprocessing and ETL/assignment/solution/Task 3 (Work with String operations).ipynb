# %% [markdown]
# # Task 3 (Work with String operations)
#
# 1. Using titanic_full.csv dataset, extract Mr,Miss,Mrs,etc.. from 'Name' column and use it to create new column and call it 'Title', then plot a countplot
# showing the count for each title in the dataset.
# 2. Using sendy_logistics.csv extract user_id in a seperate column

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 10)}, font_scale=1.2)

# %% [markdown]
# **1) Using titanic_full.csv dataset, extract Mr,Miss,Mrs,etc.. from 'Name' column and use it to create new column and call it 'Title', then plot a countplot showing the count for each title in the dataset.**

# %%
df = pd.read_csv('../../code/dastasets/titanic_full.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def extract_title(name):
    if 'Mr.' in name:
        return 'Mr'
    elif 'Miss.' in name:
        return 'Miss'
    elif 'Mrs.' in name:
        return 'Mrs'
    else:
        return 'Untitled'

df['Title'] = df['Name'].apply(extract_title)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(x='Title', data=df)

# %% [markdown]
# **2) Using sendy_logistics.csv extract user_id in a seperate column**

# %%
df = pd.read_csv('../../code/dastasets/sendy_logistics.csv')
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
def extract_user_id(user_id_txt):
    return user_id_txt.split('_')[2]

df['user_id'] = df['User Id'].apply(extract_user_id)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...
