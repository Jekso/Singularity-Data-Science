# %% [markdown]
# # Geospatial Features
# In this notebook we will learn about geographic data and how to work with them

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 10)}, font_scale=1.2)

# %% [markdown]
# ### 1) Work with Lat and Long
#
# we will use this library: https://pypi.org/project/geopy/

# %% [markdown]
# **1) Measuring Distance**

# %%
from geopy.distance import great_circle

my_home = (30.109919, 31.308797) # (lat, long)
my_cafe = (30.120982, 31.322026)

great_circle(my_home, my_cafe).kilometers
# Out:
# 1.7698508016026915

# %% [markdown]
# ***So Lets use it with Our data***

# %%
df = pd.read_csv('../dastasets/sendy_logistics.csv')
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
def get_dist(x):
    loc_1 = (x['Pickup Lat'], x['Pickup Long'])
    loc_2 = (x['Destination Lat'], x['Destination Long'])
    return great_circle(loc_1, loc_2).kilometers

df['Dist_Pick_Dest'] = df.apply(get_dist, axis=1)
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Distance (KM)  Temperature  \
# 0                                5  ...             4         20.4
# 1                                5  ...            16         26.4
# 2                                2  ...             3          NaN
# 3                                5  ...             9         19.2
# 4                                1  ...             9         15.4
#
#    Precipitation in millimeters Pickup Lat  Pickup Long  Destination Lat  \
# 0                           NaN  -1.317755    36.830370        -1.300406
# 1                           NaN  -1.351453    36.899315        -1.295004
# 2                           NaN  -1.308284    36.843419        -1.300921
# 3                           NaN  -1.281301    36.832396        -1.257147
# 4                           NaN  -1.266597    36.792118        -1.295041
#
#   Destination Long      Rider Id  Time from Pickup to Arrival Dist_Pick_Dest
# 0        36.829741  Rider_Id_432                          745       1.930336
# 1        36.814358  Rider_Id_856                         1993      11.339865
# 2        36.828195  Rider_Id_155                          455       1.880081
# 3        36.795063  Rider_Id_855                         1341       4.943465
# 4        36.809817  Rider_Id_770                         1214       3.724834
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 2) Geocoding features to get the address from lat, long or reverse.
#
# we will use this library: https://pypi.org/project/geopy/

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="Data Science course")

# %%
location = geolocator.geocode("Cairo Festival, Cairo, Egypt")
location.raw
# Out:
# {'place_id': 182256806,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 391188133,
#  'boundingbox': ['29.9788956', '29.9793241', '31.3509681', '31.3514603'],
#  'lat': '29.979109899999997',
#  'lon': '31.351214207251118',
#  'display_name': 'Malvern College Egypt, B2-B3, الطريق الدائري, المشتل, القاهرة, محافظة القاهرة, 11771, مصر',
#  'class': 'building',
#  'type': 'garage',
#  'importance': 0.32419316294807804}

# %%
location.raw['lat'], location.raw['lon']
# Out:
# ('29.979109899999997', '31.351214207251118')

# %%
location = geolocator.reverse("29.981650417493046, 31.428900499194086")
location.raw
# Out:
# {'place_id': 169546911,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 338687680,
#  'lat': '29.981712255603348',
#  'lon': '31.428962900166752',
#  'display_name': 'التجمع الثالث, مدينة القاهرة الجديدة, محافظة القاهرة, 11835, مصر',
#  'address': {'neighbourhood': 'التجمع الثالث',
#   'city': 'مدينة القاهرة الجديدة',
#   'state': 'محافظة القاهرة',
#   'postcode': '11835',
#   'country': 'مصر',
#   'country_code': 'eg'},
#  'boundingbox': ['29.9785046', '29.9825297', '31.4280647', '31.4292666']}

# %%
location.raw['address']['country']
# Out:
# 'مصر'

# %%
location.raw['address']['city']
# Out:
# 'مدينة القاهرة الجديدة'

# %% [markdown]
# ***So Lets use it with Our data***

# %%
df = pd.read_csv('../dastasets/sendy_logistics.csv').sample(20)
df.head()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 7766   Order_No_26997  User_Id_3201         Bike              3
# 10038  Order_No_21267  User_Id_2701         Bike              3
# 430    Order_No_13783  User_Id_2330         Bike              1
# 1237    Order_No_2372  User_Id_1500         Bike              3
# 553     Order_No_4854  User_Id_2946         Bike              2
#
#       Personal or Business  Placement - Day of Month  \
# 7766              Business                        12
# 10038             Business                        24
# 430               Business                         6
# 1237              Business                        28
# 553               Personal                        18
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 7766                              2       2:27:41 PM
# 10038                             5      11:31:27 AM
# 430                               6       4:30:11 PM
# 1237                              4      12:56:43 PM
# 553                               3      12:39:16 PM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  ...  \
# 7766                            12                                2  ...
# 10038                           24                                5  ...
# 430                              6                                6  ...
# 1237                            28                                4  ...
# 553                             18                                3  ...
#
#       Arrival at Destination - Time  Distance (KM)  Temperature  \
# 7766                     2:53:50 PM              2         26.9
# 10038                   12:11:01 PM              4         21.3
# 430                      5:23:31 PM             12         25.3
# 1237                     1:35:26 PM              8         27.3
# 553                      1:13:24 PM              8         19.8
#
#       Precipitation in millimeters  Pickup Lat  Pickup Long Destination Lat  \
# 7766                           NaN   -1.255189    36.782203       -1.258414
# 10038                          NaN   -1.276574    36.851365       -1.290894
# 430                            NaN   -1.292000    36.904002       -1.228432
# 1237                           NaN   -1.300406    36.829741       -1.263818
# 553                            NaN   -1.274966    36.765878       -1.298346
#
#        Destination Long      Rider Id Time from Pickup to Arrival
# 7766          36.804800  Rider_Id_647                         342
# 10038         36.822971  Rider_Id_338                         976
# 430           36.875706  Rider_Id_397                         673
# 1237          36.793006  Rider_Id_953                          17
# 553           36.814000  Rider_Id_634                        1051
#
# [5 rows x 29 columns]

# %%
def get_city(x):
    location = geolocator.reverse(f"{x['Pickup Lat']}, {x['Pickup Long']}")
    return location.raw['address']['city']

df['Country'] = df.apply(get_city, axis=1)
df.head()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 7766   Order_No_26997  User_Id_3201         Bike              3
# 10038  Order_No_21267  User_Id_2701         Bike              3
# 430    Order_No_13783  User_Id_2330         Bike              1
# 1237    Order_No_2372  User_Id_1500         Bike              3
# 553     Order_No_4854  User_Id_2946         Bike              2
#
#       Personal or Business  Placement - Day of Month  \
# 7766              Business                        12
# 10038             Business                        24
# 430               Business                         6
# 1237              Business                        28
# 553               Personal                        18
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 7766                              2       2:27:41 PM
# 10038                             5      11:31:27 AM
# 430                               6       4:30:11 PM
# 1237                              4      12:56:43 PM
# 553                               3      12:39:16 PM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  ...  \
# 7766                            12                                2  ...
# 10038                           24                                5  ...
# 430                              6                                6  ...
# 1237                            28                                4  ...
# 553                             18                                3  ...
#
#       Distance (KM)  Temperature  Precipitation in millimeters Pickup Lat  \
# 7766              2         26.9                           NaN  -1.255189
# 10038             4         21.3                           NaN  -1.276574
# 430              12         25.3                           NaN  -1.292000
# 1237              8         27.3                           NaN  -1.300406
# 553               8         19.8                           NaN  -1.274966
#
#        Pickup Long  Destination Lat Destination Long      Rider Id  \
# 7766     36.782203        -1.258414        36.804800  Rider_Id_647
# 10038    36.851365        -1.290894        36.822971  Rider_Id_338
# 430      36.904002        -1.228432        36.875706  Rider_Id_397
# 1237     36.829741        -1.263818        36.793006  Rider_Id_953
# 553      36.765878        -1.298346        36.814000  Rider_Id_634
#
#        Time from Pickup to Arrival  Country
# 7766                           342  Nairobi
# 10038                          976  Nairobi
# 430                            673  Nairobi
# 1237                            17  Nairobi
# 553                           1051  Nairobi
#
# [5 rows x 30 columns]

# %%
df['Country'].value_counts()
# Out:
# Nairobi                      19
# Central Business District     1
# Name: Country, dtype: int64

# %% [markdown]
# # Great Work!
