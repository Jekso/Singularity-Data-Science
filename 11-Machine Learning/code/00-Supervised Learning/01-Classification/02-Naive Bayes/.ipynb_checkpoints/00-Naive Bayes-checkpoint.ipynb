# %% [markdown]
# # Naive Bayes
#
# <img src='https://miro.medium.com/max/1200/0*qFuHAV7Vd09064q-.jpeg'>
#
# ## Table of contents
# 1. Import data
# 2. Data analysis & Visualization
# 3. Data Preprocessing
# 4. Train Model
# 5. Evaluate Model

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.2)

# %% [markdown]
# ### 1) Import Data

# %%
df = pd.read_csv('sentiment.csv',sep='\t',names=['Liked','Tweet'])

# %%
df
# Out:
#       Liked                                              Tweet
# 0         1            The Da Vinci Code book is just awesome.
# 1         1  this was the first clive cussler i've ever rea...
# 2         1                   i liked the Da Vinci Code a lot.
# 3         1                   i liked the Da Vinci Code a lot.
# 4         1  I liked the Da Vinci Code but it ultimatly did...
# ...     ...                                                ...
# 6913      0                     Brokeback Mountain was boring.
# 6914      0       So Brokeback Mountain was really depressing.
# 6915      0  As I sit here, watching the MTV Movie Awards, ...
# 6916      0    Ok brokeback mountain is such a horrible movie.
# 6917      0   Oh, and Brokeback Mountain was a terrible movie.
#
# [6918 rows x 2 columns]

# %% [markdown]
# ### 2) Data analysis & Visualization

# %%
sns.countplot(x='Liked', data=df)

# %% [markdown]
# ### 3) Data Preprocessing

# %%
x = df["Tweet"]
y = df["Liked"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=22)

# %%
tfidv = TfidfVectorizer(stop_words='english')
tfidv.fit(x_train)
# Out:
# TfidfVectorizer(stop_words='english')

# %%
x_train = tfidv.transform(x_train)
x_test = tfidv.transform(x_test)

# %%
x_train.shape
# Out:
# (5534, 1619)

# %%
print(x_train)
# Out:
#   (0, 1505)	0.47742011205350277
#   (0, 1493)	0.47742011205350277
#   (0, 1463)	0.47742011205350277
#   (0, 1264)	0.24684298322089232
#   (0, 1112)	0.12261547502661818
#   (0, 901)	0.13235346319531108
#   (0, 662)	0.12261547502661818
#   (0, 469)	0.45573249039680497
#   (1, 1528)	0.4676307580576898
#   (1, 327)	0.4676307580576898
#   (1, 257)	0.46749956419508276
#   (1, 102)	0.5865893842494838
#   (2, 1528)	0.24990496242899832
#   (2, 1451)	0.5769429872176121
#   (2, 1380)	0.38131025398986684
#   (2, 327)	0.24990496242899832
#   (2, 257)	0.24983485156323343
#   (2, 139)	0.5782878575188142
#   (3, 1382)	0.7444754452072445
#   (3, 1112)	0.4720997307155952
#   (3, 662)	0.4720997307155952
#   (4, 978)	0.5314897842303061
#   (4, 180)	0.5314897842303061
#   (4, 102)	0.6595735125955599
#   (5, 978)	0.2984223527148636
#   :	:
#   (5530, 901)	0.5356488963554125
#   (5530, 327)	0.48758371448716364
#   (5530, 257)	0.4874469228203504
#   (5531, 1528)	0.4235137725521013
#   (5531, 1382)	0.6797123512138209
#   (5531, 327)	0.4235137725521013
#   (5531, 257)	0.42339495571481894
#   (5532, 1022)	0.5862318347859362
#   (5532, 980)	0.40693809629678696
#   (5532, 978)	0.2799945951664353
#   (5532, 719)	0.5778751379156485
#   (5532, 180)	0.2799945951664353
#   (5533, 1607)	0.275840047605197
#   (5533, 1529)	0.31871277748648863
#   (5533, 1495)	0.31871277748648863
#   (5533, 1383)	0.31871277748648863
#   (5533, 1264)	0.2709109828379834
#   (5533, 1112)	0.13457088557741853
#   (5533, 901)	0.1452583594979734
#   (5533, 791)	0.31871277748648863
#   (5533, 662)	0.13457088557741853
#   (5533, 492)	0.31871277748648863
#   (5533, 295)	0.31871277748648863
#   (5533, 212)	0.31871277748648863
#   (5533, 159)	0.2866287290008321

# %%
tfidv.get_feature_names()
# Out:
# ['007',
#  '10',
#  '10pm',
#  '12',
#  '17',
#  '1984',
#  '1st',
#  '200',
#  '2007',
#  '286',
#  '2nd',
#  '31st',
#  '33',
#  '3333',
#  '385',
#  '50',
#  '517',
#  '648',
#  '6th',
#  '700',
#  '7th',
#  '8230',
#  '9am',
#  'aaron',
#  'able',
#  'abortion',
#  'abrams',
#  'absolutely',
#  'absurd',
#  'academy',
#  'acceptable',
#  'accompaniment',
#  'account',
#  'achieved',
#  'aching',
#  'acne',
#  'acoustic',
#  'acting',
#  'action',
#  'actor',
#  'actors',
#  'actually',
#  'add',
#  'addition',
#  'admired',
#  'admiring',
#  'adorable',
#  'adore',
#  'adult',
#  'afterschool',
#  'ago',
#  'agree',
#  'agreed',
#  'ah',
#  'aka',
#  'al',
#  'allegedly',
#  'amazing',
#  'amazingly',
#  'america',
#  'amã',
#  'anatomy',
#  'ang',
#  'angel',
#  'angels',
#  'angle',
#  'anime',
#  'aniwae',
#  'anne',
#  'answers',
#  'anyways',
#  'ap',
#  'apart',
#  'apologized',
#  'apparently',
#  'appeal',
#  'appeals',
#  'aren',
#  'arenas',
#  'arguments',
#  'arse',
#  'artemis',
#  'article',
#  'ashamed',
#  'asian',
#  'aside',
#  'ask',
#  'asking',
#  'asleep',
#  'ass',
#  'asshole',
#  'association',
#  'astonishingly',
#  'ate',
#  'atrocious',
#  'attempt',
#  'attractive',
#  'audrey',
#  'author',
#  'avatar',
#  'awards',
#  'away',
#  'awesome',
#  'awesomest',
#  'awful',
#  'azkaban',
#  'baby',
#  'bachelor',
#  'backdrop',
#  'background',
#  'backtory',
#  'backward',
#  'bad',
#  'badness',
#  'ball',
#  'balls',
#  'ballz',
#  'ban',
#  'bangs',
#  'barry',
#  'basically',
#  'basket',
#  'bbm',
#  'beach',
#  'beans',
#  'beat',
#  'beating',
#  'beatles',
#  'beautiful',
#  'becuase',
#  'began',
#  'begin',
#  'believe',
#  'belong',
#  'bentlys',
#  'best',
#  'bet',
#  'better',
#  'biased',
#  'big',
#  'biggie',
#  'bit',
#  'bitch',
#  'bitter',
#  'black',
#  'blame',
#  'blashpemies',
#  'blasphying',
#  'bless',
#  'blog',
#  'blonds',
#  'blood',
#  'blows',
#  'board',
#  'bobbypin',
#  'body',
#  'bogus',
#  'bolsters',
#  'bonkers',
#  'book',
#  'books',
#  'bootlegged',
#  'bored',
#  'boring',
#  'bought',
#  'bound',
#  'bout',
#  'boycott',
#  'boycotted',
#  'boycotting',
#  'boys',
#  'boyy',
#  'brazil',
#  'bridget',
#  'briefly',
#  'brigid',
#  'brilliant',
#  'bringing',
#  'bro',
#  'broke',
#  'brokeback',
#  'brooke',
#  'broom',
#  'brown',
#  'btw',
#  'budget',
#  'bullshit',
#  'bunch',
#  'burbank',
#  'burnt',
#  'butt',
#  'bye',
#  'ca',
#  'cake',
#  'calif',
#  'called',
#  'calling',
#  'calls',
#  'came',
#  'campaign',
#  'canceled',
#  'candy',
#  'capote',
#  'care',
#  'career',
#  'carefully',
#  'caribbean',
#  'cars',
#  'casanova',
#  'case',
#  'cast',
#  'catch',
#  'catcher',
#  'category',
#  'causing',
#  'center',
#  'challenge',
#  'chamber',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'character',
#  'characterization',
#  'characters',
#  'cheapened',
#  'chick',
#  'chicken',
#  'childishly',
#  'children',
#  'chinese',
#  'choice',
#  'chris',
#  'christ',
#  'christain',
#  'christian',
#  'christianity',
#  'christmas',
#  'christopher',
#  'chronicles',
#  'chronological',
#  'cinema',
#  'claiming',
#  'class',
#  'classes',
#  'classic',
#  'clean',
#  'cleaning',
#  'clearly',
#  'clive',
#  'cloak',
#  'clothed',
#  'club',
#  'clubbin',
#  'cobequid',
#  'cock',
#  'cocktail',
#  'code',
#  'coherent',
#  'cold',
#  'colfer',
#  'collection',
#  'college',
#  'colony',
#  'colourfully',
#  'combining',
#  'combonation',
#  'come',
#  'comes',
#  'coming',
#  'comment',
#  'comments',
#  'community',
#  'compared',
#  'comparsions',
#  'complaints',
#  'completely',
#  'complex',
#  'conclusion',
#  'condeming',
#  'condemnation',
#  'confess',
#  'congrats',
#  'conquering',
#  'consider',
#  'considered',
#  'consumed',
#  'contains',
#  'controversy',
#  'conversations',
#  'convo',
#  'cool',
#  'copy',
#  'corrupting',
#  'costumes',
#  'count',
#  'counting',
#  'course',
#  'cover',
#  'cow',
#  'cowan',
#  'cowboy',
#  'cowboys',
#  'coz',
#  'crafted',
#  'crap',
#  'crappy',
#  'crash',
#  'crazy',
#  'created',
#  'creature',
#  'credit',
#  'creed',
#  'cried',
#  'cringe',
#  'criticized',
#  'criticizers',
#  'critics',
#  'cruise',
#  'crusade',
#  'crystal',
#  'cucumber',
#  'culture',
#  'cussler',
#  'cut',
#  'cute',
#  'cuz',
#  'da',
#  'dad',
#  'daddy',
#  'dakota',
#  'damn',
#  'dan',
#  'dance',
#  'daniel',
#  'danielle',
#  'darkness',
#  'dart',
#  'dash',
#  'date',
#  'dating',
#  'davinci',
#  'day',
#  'days',
#  'deals',
#  'dearly',
#  'death',
#  'debates',
#  'decaying',
#  'decent',
#  'decide',
#  'decided',
#  'deciding',
#  'decline',
#  'decomposing',
#  'dedicated',
#  'deemed',
#  'deep',
#  'defensive',
#  'definately',
#  'definitely',
#  'degraw',
#  'delicious',
#  'demeantor',
#  'dementors',
#  'demons',
#  'depp',
#  'depressing',
#  'depth',
#  'derek',
#  'deserved',
#  'desperate',
#  'desperately',
#  'despise',
#  'despised',
#  'devastate',
#  'devil',
#  'diana',
#  'dick',
#  'dictate',
#  'did',
#  'didn',
#  'didnt',
#  'didnâ',
#  'die',
#  'died',
#  'dies',
#  'different',
#  'differently',
#  'dinner',
#  'directed',
#  'director',
#  'disappointed',
#  'disappointing',
#  'discovered',
#  'discuss',
#  'discussed',
#  'discussing',
#  'dislike',
#  'disliked',
#  'disney',
#  'disruption',
#  'dissapointed',
#  'diversity',
#  'does',
#  'doesn',
#  'dogfucking',
#  'dogtown',
#  'doing',
#  'don',
#  'donkey',
#  'dont',
#  'donâ',
#  'doors',
#  'dork',
#  'dorks',
#  'draco',
#  'dragged',
#  'dragons',
#  'drain',
#  'draw',
#  'drawing',
#  'drawn',
#  'dream',
#  'dress',
#  'drive',
#  'dudeee',
#  'dumb',
#  'dumbest',
#  'dumbledor',
#  'durno',
#  'dvds',
#  'dynamite',
#  'earrings',
#  'eating',
#  'edition',
#  'editor',
#  'education',
#  'eek',
#  'effects',
#  'egg',
#  'eh',
#  'emily',
#  'emma',
#  'emo',
#  'encourage',
#  'end',
#  'ending',
#  'energy',
#  'england',
#  'english',
#  'enjoy',
#  'enjoyed',
#  'enjoying',
#  'enjoyment',
#  'enjoys',
#  'ennis',
#  'entire',
#  'entitled',
#  'eoin',
#  'equal',
#  'equally',
#  'equus',
#  'eragon',
#  'erm',
#  'escapades',
#  'especially',
#  'esther',
#  'et',
#  'events',
#  'everybody',
#  'evil',
#  'evilpinkmunky',
#  'ew',
#  'example',
#  'excellent',
#  'excited',
#  'exciting',
#  'executed',
#  'exelent',
#  'exhausted',
#  'expected',
#  'explaination',
#  'explains',
#  'explore',
#  'explosions',
#  'expo',
#  'exponentially',
#  'exquisite',
#  'extent',
#  'extremely',
#  'eye',
#  'eyre',
#  'fabricated',
#  'fabulous',
#  'facebook',
#  'facile',
#  'facing',
#  'fact',
#  'fade',
#  'fair',
#  'fairly',
#  'fall',
#  'fallon',
#  'families',
#  'fan',
#  'fandom',
#  'fanfic',
#  'fanfiction',
#  'fantasy',
#  'far',
#  'fat',
#  'fault',
#  'favor',
#  'favorite',
#  'favourite',
#  'feast',
#  'feathers',
#  'feel',
#  'feeling',
#  'felicia',
#  'fell',
#  'felt',
#  'festivities',
#  'fiber',
#  'fic',
#  'field',
#  'figure',
#  'figured',
#  'figures',
#  'film',
#  'films',
#  'final',
#  'finale',
#  'finally',
#  'finals',
#  'finish',
#  'finished',
#  'finshed',
#  'fireworks',
#  'fit',
#  'fits',
#  'flat',
#  'flick',
#  'folk',
#  'folows',
#  'food',
#  'forever',
#  'forget',
#  'forgotten',
#  'form',
#  'formed',
#  'fowl',
#  'fr',
#  'frakking',
#  'france',
#  'franchise',
#  'freagin',
#  'freak',
#  'freakin',
#  'freaking',
#  'free',
#  'freezing',
#  'frenzied',
#  'friday',
#  'friend',
#  'friends',
#  'friendships',
#  'friggin',
#  'frodo',
#  'fuck',
#  'fucking',
#  'fully',
#  'fun',
#  'funniest',
#  'funny',
#  'futile',
#  'future',
#  'fyi',
#  'gadgets',
#  'gaither',
#  'game',
#  'garrett',
#  'gary',
#  'gathered',
#  'gavin',
#  'gay',
#  'gayer',
#  'gayness',
#  'gays',
#  'geek',
#  'generalized',
#  'generally',
#  'generation',
#  'genre',
#  'genres',
#  'georgia',
#  'getting',
#  'gettting',
#  'giants',
#  'gift',
#  'gin',
#  'girl',
#  'girls',
#  'given',
#  'gl',
#  'glad',
#  'glitz',
#  'gn',
#  'goblet',
#  'god',
#  'goes',
#  'goin',
#  'going',
#  'gonna',
#  'good',
#  'google',
#  'gorgeous',
#  'gossip',
#  'got',
#  'goth',
#  'gotta',
#  'grabs',
#  'grand',
#  'great',
#  'grey',
#  'groaning',
#  'ground',
#  'group',
#  'grow',
#  'grown',
#  'gun',
#  'guts',
#  'guy',
#  'guys',
#  'gyllenhaal',
#  'gym',
#  'haha',
#  'hahaha',
#  'hahahaha',
#  'hahahahahaha',
#  'hahash',
#  'haircut',
#  'hairy',
#  'half',
#  'halfway',
#  'hall',
#  'halle',
#  'halloween',
#  'halls',
#  'hammy',
#  'hand',
#  'hands',
#  'hanging',
#  'hank',
#  'happen',
#  'happened',
#  'happiness',
#  'happy',
#  'hard',
#  'hardcore',
#  'harrison',
#  'harry',
#  'hat',
#  'hate',
#  'hated',
#  'hates',
#  'hating',
#  'haunt',
#  'haunted',
#  'haven',
#  'having',
#  'head',
#  'health',
#  'hear',
#  'heard',
#  'heart',
#  'heartbraking',
#  'heath',
#  'heather',
#  'heavy',
#  'hedge',
#  'hell',
#  'hella',
#  'hello',
#  'helped',
#  'heresies',
#  'hermione',
#  'hero',
#  'het',
#  'heteronormativity',
#  'hey',
#  'hide',
#  'hilarious',
#  'hill',
#  'hippie',
#  'hips',
#  'historical',
#  'hoffman',
#  'hogwarts',
#  'hogwash',
#  'hold',
#  'holding',
#  'hollywood',
#  'hollywoord',
#  'holy',
#  'home',
#  'homophobes',
#  'homophobic',
#  'homosexuality',
#  'honestly',
#  'honor',
#  'hooked',
#  'hooker',
#  'hookup',
#  'hoot',
#  'hoover',
#  'hope',
#  'hopefully',
#  'horrible',
#  'horses',
#  'hot',
#  'hour',
#  'hours',
#  'house',
#  'howard',
#  'hp',
#  'huge',
#  'hugged',
#  'hugh',
#  'huh',
#  'humor',
#  'hung',
#  'hype',
#  'hyped',
#  'icons',
#  'idea',
#  'ideas',
#  'idiots',
#  'idk',
#  'iii',
#  'illegally',
#  'illustrated',
#  'im',
#  'image',
#  'imagine',
#  'immediately',
#  'immensely',
#  'immortal',
#  'imo',
#  'important',
#  'impossible',
#  'impressive',
#  'inaccurate',
#  'included',
#  'including',
#  'increasing',
#  'incredible',
#  'incredibly',
#  'independant',
#  'independent',
#  'indicative',
#  'indoctrinate',
#  'industry',
#  'infiltrate',
#  'inherently',
#  'insane',
#  'insanely',
#  'inside',
#  'inspired',
#  'instead',
#  'insurance',
#  'intellectual',
#  'interested',
#  'interesting',
#  'interview',
#  'intrigued',
#  'invisibility',
#  'invisible',
#  'involve',
#  'iq',
#  'irrespective',
#  'isn',
#  'issues',
#  'ive',
#  'jack',
#  'jackson',
#  'jake',
#  'jamaica',
#  'jame',
#  'jamie',
#  'jane',
#  'japenese',
#  'jay',
#  'jelly',
#  'jenn',
#  'jessica',
#  'jesus',
#  'jill',
#  'job',
#  'joe',
#  'john',
#  'johnny',
#  'joiners',
#  'joining',
#  'joke',
#  'jokes',
#  'jon',
#  'jones',
#  'josie',
#  'joy',
#  'judgement',
#  'juicy',
#  'julia',
#  'just',
#  'kaka',
#  'kanye',
#  'kat',
#  'kate',
#  'kelse',
#  'kelsie',
#  'kept',
#  'keys',
#  'kick',
#  'kicked',
#  'kid',
#  'kids',
#  'kill',
#  'kind',
#  'kinda',
#  'kirsten',
#  'kiss',
#  'knew',
#  'knight',
#  'knights',
#  'know',
#  'knows',
#  'kudos',
#  'la',
#  'laid',
#  'lama',
#  'lame',
#  'lamest',
#  'lapse',
#  'larry',
#  'lately',
#  'later',
#  'latest',
#  'latin',
#  'laughed',
#  'laura',
#  'lazy',
#  'leah',
#  'learn',
#  'leder',
#  'lee',
#  'left',
#  'legacy',
#  'lends',
#  'let',
#  'lets',
#  'letter',
#  'letting',
#  'level',
#  'libraries',
#  'libre',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'liked',
#  'likes',
#  'lil',
#  'lines',
#  'linked',
#  'listen',
#  'listens',
#  'lit',
#  'literature',
#  'little',
#  'live',
#  'livejournal',
#  'lives',
#  'living',
#  'll',
#  'loathe',
#  'lol',
#  'long',
#  'longer',
#  'look',
#  'looked',
#  'looks',
#  'lord',
#  'lords',
#  'lore',
#  'loser',
#  'lost',
#  'lot',
#  'lotr',
#  'loudest',
#  'lousy',
#  'love',
#  'loved',
#  'loves',
#  'low',
#  'lower',
#  'luau',
#  'lubb',
#  'luck',
#  'lucky',
#  'lunch',
#  'luv',
#  'lynn',
#  'lynne',
#  'machine',
#  'madly',
#  'madre',
#  'magic',
#  'magical',
#  'main',
#  'mainstream',
#  'major',
#  'majorly',
#  'make',
#  'making',
#  'malaguena',
#  'malfoy',
#  'mall',
#  'man',
#  'mang',
#  'manga',
#  'march',
#  'marcia',
#  'margaritas',
#  'marisa',
#  'master',
#  'match',
#  'material',
#  'matter',
#  'maybe',
#  'mcgarther',
#  'mcmurtry',
#  'mcphee',
#  'mean',
#  'measure',
#  'meat',
#  'media',
#  'meeting',
#  'melbourne',
#  'men',
#  'mention',
#  'mentioned',
#  'messiah',
#  'messy',
#  'mi',
#  'mi3',
#  'microsoft',
#  'million',
#  'min',
#  'mind',
#  'mindedness',
#  'minutes',
#  'mirror',
#  'miss',
#  'mission',
#  'mob',
#  'mocking',
#  'moives',
#  'mom',
#  'moments',
#  'monchel',
#  'money',
#  'monsters',
#  'mood',
#  'moralistic',
#  'mormon',
#  'mother',
#  'mound',
#  'mountain',
#  'mouth',
#  'movie',
#  'movies',
#  'moving',
#  'mph',
#  'mrs',
#  'mtv',
#  'muahahaahahah',
#  'murderball',
#  'music',
#  'musiclove',
#  'mybutthole',
#  'nacho',
#  'nanny',
#  'napoleon',
#  'narnia',
#  'nasy',
#  'nc',
#  'near',
#  'nearly',
#  'need',
#  ...]

# %% [markdown]
# ### 4) Train Model

# %%
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# ### 5) Evaluate Model

# %%
# test the model on the test_set
y_pred = model.predict(x_test)

# %%
#calculate the accuracy
accuracy_score(y_test, y_pred)
# Out:
# 0.9819364161849711

# %%
#print confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[580,  18],
#        [  7, 779]], dtype=int64)

# %% [markdown]
# ### 6) Custom testing

# %%
model.predict(tfidv.transform(['I love The Matrix Movie']))
# Out:
# array([1], dtype=int64)

# %%
model.predict(tfidv.transform(['I hate The Matrix Movie']))
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Great Work!
