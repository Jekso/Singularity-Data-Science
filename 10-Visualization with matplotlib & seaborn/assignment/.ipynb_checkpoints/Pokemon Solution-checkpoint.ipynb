# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.2)

# %%
df = pd.read_csv('Pokemon.csv', encoding='latin1')
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
df = df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    Int64
#  1   Name       151 non-null    string
#  2   Type 1     151 non-null    string
#  3   Type 2     67 non-null     string
#  4   Total      151 non-null    Int64
#  5   HP         151 non-null    Int64
#  6   Attack     151 non-null    Int64
#  7   Defense    151 non-null    Int64
#  8   Sp. Atk    151 non-null    Int64
#  9   Sp. Def    151 non-null    Int64
#  10  Speed      151 non-null    Int64
#  11  Stage      151 non-null    Int64
#  12  Legendary  151 non-null    boolean
# dtypes: Int64(9), boolean(1), string(3)
# memory usage: 15.9 KB

# %%
sns.distplot(df['Total'], kde=False)

# %%
sns.kdeplot(df['HP'], shade=True)

# %%
sns.kdeplot(df['Speed'], shade=True)

# %%
sns.jointplot(x='Attack', y='Defense', data=df)

# %%
sns.jointplot(x='HP', y='Speed', data=df, kind='kde')

# %%
sns.countplot(x='Stage', data=df, palette='viridis')

# %%
sns.countplot(x='Type 2', data=df, palette='viridis')

# %%
sns.boxplot(y='Type 1', x='HP', data=df, palette='viridis')

# %%
sns.boxplot(y='Type 1', x='Attack', data=df, palette='viridis')

# %%
sns.stripplot(y='Type 1', x='Attack', data=df, palette='viridis')

# %%
sns.stripplot(y='Speed', x='Stage', data=df, palette='viridis')

# %%
sns.stripplot(y='Speed', x='Stage', data=df, palette='rocket', hue='Legendary', dodge=True)

# %%
sns.barplot(x='Type 2', y='HP', data=df, palette='rocket')

# %% [markdown]
# # Great Work!
